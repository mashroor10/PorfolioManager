# %%
import requests
import pandas as pd
import re
from sqlalchemy import create_engine, inspect
from dotenv import load_dotenv
import os   
# Load environment variables from .env file
load_dotenv()
# Define the API key



api_key = os.getenv('api_key')

# %%
class PostgresManager:
    def __init__(self, host, port, dbname, user, password):
        self.db_params = {
            'host': host,
            'port': port,
            'dbname': dbname,
            'user': user,
            'password': password
        }
        self.engine_str = (
            f"postgresql://{user}:{password}@{host}:{port}/{dbname}"
        )
        self.engine = create_engine(self.engine_str)
        print("✅ PostgreSQL connection initialized.")

    def upload_dataframe(self, df: pd.DataFrame, table_name: str, if_exists='replace'):
        """
        Uploads a DataFrame to PostgreSQL.
        - if_exists: 'replace', 'append', or 'fail'
        """
        try:
            df.to_sql(table_name, self.engine, if_exists=if_exists, index=False, method='multi')
            print(f"✅ Data uploaded to table '{table_name}'.")
        except Exception as e:
            print(f"❌ Failed to upload to '{table_name}': {e}")

    def get_tickers_from_30min_tables(self):
        """
        Extracts all tickers from tables that match the {ticker}_30MinData format.
        """
        try:
            inspector = inspect(self.engine)
            all_tables = inspector.get_table_names()
            pattern = re.compile(r'^(.*)_30MinData$', re.IGNORECASE)
            tickers = [match.group(1).upper() for table in all_tables if (match := pattern.match(table))]
            return tickers
        except Exception as e:
            print(f"❌ Failed to inspect tables: {e}")
            return []

# ✅ Example Usage:
pg = PostgresManager(
    host=os.getenv('host'),
    port=os.getenv('port'),
    dbname=os.getenv('dbname'),
    user=os.getenv('user'),
    password=os.getenv('password')
)

# Upload example:
# pg.upload_dataframe(your_dataframe, 'YourTableName')

# Get ticker names
tickers = pg.get_tickers_from_30min_tables()
print("Tickers found:", tickers)
# Out:
# ✅ PostgreSQL connection initialized.
# Tickers found: ['AVGO', 'MA', 'JNJ', 'PM', 'IBM', 'NOW', 'TBB', 'RTX', 'ADBE', 'SCHW', 'TMO', 'C', 'GILD', 'PANW', 'CMCSA', 'MU', 'APH', 'BX', 'ICE', 'WELL', 'AMT', 'BMYMP', 'SOJC', 'CEG', 'HCA', 'DUKB', 'IBKR', 'ELV', 'INTC', 'AJG', 'TDG', 'CVS', 'RSG', 'ORLY', 'MMM', 'DELL', 'SCCO', 'APO', 'ZTS', 'ECL', 'SNPS', 'RCL', 'BRK-B', 'NFLX', 'HD', 'TMUS', 'WFC', 'AXP', 'ISRG', 'VZ', 'TXN', 'SPGI', 'BSX', 'TJX', 'RCIT', 'PFE', 'COF', 'CRWD', 'LMT', 'COP', 'MSFT', 'BRK-A', 'ORCL', 'BAC', 'UNH', 'CVX', 'NVDA', 'TSLA', 'COST', 'ABBV', 'GE', 'ABT', 'MS', 'MRK', 'BKNG', 'CAT', 'BA', 'NEE', 'APP', 'AMAT', 'ADP', 'LOW', 'VRTX', 'LRCX', 'KKR', 'MSTR', 'PLD', 'CME', 'SOJE', 'SOJD', 'NKE', 'FI', 'SHW', 'EQIX', 'ABNB', 'PH', 'CI', 'CDNS', 'FTNT', 'AAPL', 'WMT', 'XOM', 'KO', 'CRM', 'MCD', 'DIS', 'GS', 'UBER', 'QCOM', 'AMGN', 'HON', 'DE', 'UNP', 'GEV', 'ANET', 'MMC', 'ADI', 'KLAC', 'SBUX', 'MO', 'BMY', 'SO', 'WM', 'DASH', 'CTAS', 'DUK', 'MCK', 'MCO', 'MDLZ', 'UPS', 'AMZN', 'JPM', 'GOOGL', 'GOOG', 'LLY', 'META', 'V', 'PG', 'PLTR', 'CSCO', 'INTU', 'T', 'AMD', 'PEP', 'PGR', 'BLK', 'SYK', 'DHR', 'GD', 'WMB', 'CL', 'CVNA', 'MAR', 'ITW', 'PYPL', 'HWM', 'CMG', 'PNC', 'NOC', 'SNOW', 'MSI', 'USB', 'EMR', 'EPD', 'WDAY', 'CRWV', 'HOOD', 'RBLX', 'BK', 'COIN', 'ADSK', 'KMI', 'NET', 'APD', 'EOG', 'AZO', 'TRV', 'MNST', 'AXON', 'ROP', 'ET', 'CARR', 'CSX', 'HLT', 'FCX', 'DLR', 'MRVL', 'VST', 'NEM', 'PAYX', 'NSC', 'AFL', 'COR', 'ALL', 'CHTR', 'AEP', 'LNG', 'MET', 'PWR', 'TFC', 'PSA', 'SPG', 'FDX', 'GWW', 'MPLX', 'REGN', 'OKE', 'O', 'DFS', 'AIG', 'SRE', 'BDX', 'SREA', 'AMP', 'MPC', 'NDAQ', 'PCAR', 'CTVA', 'CPRT', 'FAST', 'D', 'ROST', 'ZS', 'VEEV', 'PSX', 'SLB', 'URI', 'LHX', 'GM', 'EW', 'CMI', 'VRSK', 'KDP', 'KMB']

# %%
def get_company_profile(ticker, api_key):
    """Fetches company profile and returns a dictionary of relevant metrics."""
    url = f"https://financialmodelingprep.com/stable/profile?symbol={ticker}&apikey={api_key}"
    response = requests.get(url)
    
    if response.status_code == 200:
        try:
            data = response.json()
            if data:
                profile = data[0]
                profile['symbol'] = ticker
                return profile
        except Exception as e:
            print(f"⚠️ Error parsing data for {ticker}: {e}")
    else:
        print(f"⚠️ Failed to fetch profile for {ticker}. Status code: {response.status_code}")
    
    return None

def build_company_profile_table(tickers, api_key):
    """Returns a DataFrame where rows are companies and columns are profile metrics."""
    profiles = []

    for ticker in tickers:
        print(f"📥 Fetching profile for {ticker}")
        profile = get_company_profile(ticker, api_key)
        if profile:
            profiles.append(profile)

    if profiles:
        df = pd.DataFrame(profiles)
        df.set_index('companyName', inplace=True, drop=True)
        return df
    else:
        print("❌ No profile data collected.")
        return pd.DataFrame()

# Example usage
company_profiles_df = build_company_profile_table(tickers, api_key)

print(company_profiles_df.head())
# Out:
# 📥 Fetching profile for AVGO
# 📥 Fetching profile for MA
# 📥 Fetching profile for JNJ
# 📥 Fetching profile for PM
# 📥 Fetching profile for IBM
# 📥 Fetching profile for NOW
# 📥 Fetching profile for TBB
# 📥 Fetching profile for RTX
# 📥 Fetching profile for ADBE
# 📥 Fetching profile for SCHW
# 📥 Fetching profile for TMO
# 📥 Fetching profile for C
# 📥 Fetching profile for GILD
# 📥 Fetching profile for PANW
# 📥 Fetching profile for CMCSA
# 📥 Fetching profile for MU
# 📥 Fetching profile for APH
# 📥 Fetching profile for BX
# 📥 Fetching profile for ICE
# 📥 Fetching profile for WELL
# 📥 Fetching profile for AMT
# 📥 Fetching profile for BMYMP
# 📥 Fetching profile for SOJC
# 📥 Fetching profile for CEG
# 📥 Fetching profile for HCA
# 📥 Fetching profile for DUKB
# 📥 Fetching profile for IBKR
# 📥 Fetching profile for ELV
# 📥 Fetching profile for INTC
# 📥 Fetching profile for AJG
# 📥 Fetching profile for TDG
# 📥 Fetching profile for CVS
# 📥 Fetching profile for RSG
# 📥 Fetching profile for ORLY
# 📥 Fetching profile for MMM
# 📥 Fetching profile for DELL
# 📥 Fetching profile for SCCO
# 📥 Fetching profile for APO
# 📥 Fetching profile for ZTS
# 📥 Fetching profile for ECL
# 📥 Fetching profile for SNPS
# 📥 Fetching profile for RCL
# 📥 Fetching profile for BRK-B
# 📥 Fetching profile for NFLX
# 📥 Fetching profile for HD
# 📥 Fetching profile for TMUS
# 📥 Fetching profile for WFC
# 📥 Fetching profile for AXP
# 📥 Fetching profile for ISRG
# 📥 Fetching profile for VZ
# 📥 Fetching profile for TXN
# 📥 Fetching profile for SPGI
# 📥 Fetching profile for BSX
# 📥 Fetching profile for TJX
# 📥 Fetching profile for RCIT
# 📥 Fetching profile for PFE
# 📥 Fetching profile for COF
# 📥 Fetching profile for CRWD
# 📥 Fetching profile for LMT
# 📥 Fetching profile for COP
# 📥 Fetching profile for MSFT
# 📥 Fetching profile for BRK-A
# 📥 Fetching profile for ORCL
# 📥 Fetching profile for BAC
# 📥 Fetching profile for UNH
# 📥 Fetching profile for CVX
# 📥 Fetching profile for NVDA
# 📥 Fetching profile for TSLA
# 📥 Fetching profile for COST
# 📥 Fetching profile for ABBV
# 📥 Fetching profile for GE
# 📥 Fetching profile for ABT
# 📥 Fetching profile for MS
# 📥 Fetching profile for MRK
# 📥 Fetching profile for BKNG
# 📥 Fetching profile for CAT
# 📥 Fetching profile for BA
# 📥 Fetching profile for NEE
# 📥 Fetching profile for APP
# 📥 Fetching profile for AMAT
# 📥 Fetching profile for ADP
# 📥 Fetching profile for LOW
# 📥 Fetching profile for VRTX
# 📥 Fetching profile for LRCX
# 📥 Fetching profile for KKR
# 📥 Fetching profile for MSTR
# 📥 Fetching profile for PLD
# 📥 Fetching profile for CME
# 📥 Fetching profile for SOJE
# 📥 Fetching profile for SOJD
# 📥 Fetching profile for NKE
# 📥 Fetching profile for FI
# 📥 Fetching profile for SHW
# 📥 Fetching profile for EQIX
# 📥 Fetching profile for ABNB
# 📥 Fetching profile for PH
# 📥 Fetching profile for CI
# 📥 Fetching profile for CDNS
# 📥 Fetching profile for FTNT
# 📥 Fetching profile for AAPL
# 📥 Fetching profile for WMT
# 📥 Fetching profile for XOM
# 📥 Fetching profile for KO
# 📥 Fetching profile for CRM
# 📥 Fetching profile for MCD
# 📥 Fetching profile for DIS
# 📥 Fetching profile for GS
# 📥 Fetching profile for UBER
# 📥 Fetching profile for QCOM
# 📥 Fetching profile for AMGN
# 📥 Fetching profile for HON
# 📥 Fetching profile for DE
# 📥 Fetching profile for UNP
# 📥 Fetching profile for GEV
# 📥 Fetching profile for ANET
# 📥 Fetching profile for MMC
# 📥 Fetching profile for ADI
# 📥 Fetching profile for KLAC
# 📥 Fetching profile for SBUX
# 📥 Fetching profile for MO
# 📥 Fetching profile for BMY
# 📥 Fetching profile for SO
# 📥 Fetching profile for WM
# 📥 Fetching profile for DASH
# 📥 Fetching profile for CTAS
# 📥 Fetching profile for DUK
# 📥 Fetching profile for MCK
# 📥 Fetching profile for MCO
# 📥 Fetching profile for MDLZ
# 📥 Fetching profile for UPS
# 📥 Fetching profile for AMZN
# 📥 Fetching profile for JPM
# 📥 Fetching profile for GOOGL
# 📥 Fetching profile for GOOG
# 📥 Fetching profile for LLY
# 📥 Fetching profile for META
# 📥 Fetching profile for V
# 📥 Fetching profile for PG
# 📥 Fetching profile for PLTR
# 📥 Fetching profile for CSCO
# 📥 Fetching profile for INTU
# 📥 Fetching profile for T
# 📥 Fetching profile for AMD
# 📥 Fetching profile for PEP
# 📥 Fetching profile for PGR
# 📥 Fetching profile for BLK
# 📥 Fetching profile for SYK
# 📥 Fetching profile for DHR
# 📥 Fetching profile for GD
# 📥 Fetching profile for WMB
# 📥 Fetching profile for CL
# 📥 Fetching profile for CVNA
# 📥 Fetching profile for MAR
# 📥 Fetching profile for ITW
# 📥 Fetching profile for PYPL
# 📥 Fetching profile for HWM
# 📥 Fetching profile for CMG
# 📥 Fetching profile for PNC
# 📥 Fetching profile for NOC
# 📥 Fetching profile for SNOW
# 📥 Fetching profile for MSI
# 📥 Fetching profile for USB
# 📥 Fetching profile for EMR
# 📥 Fetching profile for EPD
# 📥 Fetching profile for WDAY
# 📥 Fetching profile for CRWV
# 📥 Fetching profile for HOOD
# 📥 Fetching profile for RBLX
# 📥 Fetching profile for BK
# 📥 Fetching profile for COIN
# 📥 Fetching profile for ADSK
# 📥 Fetching profile for KMI
# 📥 Fetching profile for NET
# 📥 Fetching profile for APD
# 📥 Fetching profile for EOG
# 📥 Fetching profile for AZO
# 📥 Fetching profile for TRV
# 📥 Fetching profile for MNST
# 📥 Fetching profile for AXON
# 📥 Fetching profile for ROP
# 📥 Fetching profile for ET
# 📥 Fetching profile for CARR
# 📥 Fetching profile for CSX
# 📥 Fetching profile for HLT
# 📥 Fetching profile for FCX
# 📥 Fetching profile for DLR
# 📥 Fetching profile for MRVL
# 📥 Fetching profile for VST
# 📥 Fetching profile for NEM
# 📥 Fetching profile for PAYX
# 📥 Fetching profile for NSC
# 📥 Fetching profile for AFL
# 📥 Fetching profile for COR
# 📥 Fetching profile for ALL
# 📥 Fetching profile for CHTR
# 📥 Fetching profile for AEP
# 📥 Fetching profile for LNG
# 📥 Fetching profile for MET
# 📥 Fetching profile for PWR
# 📥 Fetching profile for TFC
# 📥 Fetching profile for PSA
# 📥 Fetching profile for SPG
# 📥 Fetching profile for FDX
# 📥 Fetching profile for GWW
# 📥 Fetching profile for MPLX
# 📥 Fetching profile for REGN
# 📥 Fetching profile for OKE
# 📥 Fetching profile for O
# 📥 Fetching profile for DFS
# 📥 Fetching profile for AIG
# 📥 Fetching profile for SRE
# 📥 Fetching profile for BDX
# 📥 Fetching profile for SREA
# 📥 Fetching profile for AMP
# 📥 Fetching profile for MPC
# 📥 Fetching profile for NDAQ
# 📥 Fetching profile for PCAR
# 📥 Fetching profile for CTVA
# 📥 Fetching profile for CPRT
# 📥 Fetching profile for FAST
# 📥 Fetching profile for D
# 📥 Fetching profile for ROST
# 📥 Fetching profile for ZS
# 📥 Fetching profile for VEEV
# 📥 Fetching profile for PSX
# 📥 Fetching profile for SLB
# 📥 Fetching profile for URI
# 📥 Fetching profile for LHX
# 📥 Fetching profile for GM
# 📥 Fetching profile for EW
# 📥 Fetching profile for CMI
# 📥 Fetching profile for VRSK
# 📥 Fetching profile for KDP
# 📥 Fetching profile for KMB
#                                             symbol   price      marketCap  \
# companyName
# Broadcom Inc.                                 AVGO  246.93  1161052513500
# Mastercard Incorporated                         MA  590.12   531853321560
# Johnson & Johnson                              JNJ  155.03   373013032100
# Philip Morris International Inc.                PM  181.73   282866379600
# International Business Machines Corporation    IBM  268.87   249886971390
#
#                                               beta  lastDividend  \
# companyName
# Broadcom Inc.                                1.122         2.235
# Mastercard Incorporated                      1.052         2.840
# Johnson & Johnson                            0.410         5.020
# Philip Morris International Inc.             0.544         5.350
# International Business Machines Corporation  0.652         6.690
#
#                                                      range  change  \
# companyName
# Broadcom Inc.                                 128.5-265.43  -13.00
# Mastercard Incorporated                      428.86-591.16    4.68
# Johnson & Johnson                            140.68-169.99    1.37
# Philip Morris International Inc.              98.93-183.94   -0.23
# International Business Machines Corporation  166.81-270.17    2.01
#
#                                              changePercentage    volume  \
# companyName
# Broadcom Inc.                                        -5.00135  41146653
# Mastercard Incorporated                               0.79940   1217692
# Johnson & Johnson                                     0.89158   5387248
# Philip Morris International Inc.                     -0.12640   1933640
# International Business Machines Corporation           0.75320   1865615
#
#                                              averageVolume  ...  \
# companyName                                                 ...
# Broadcom Inc.                                   28515028.0  ...
# Mastercard Incorporated                          2822995.0  ...
# Johnson & Johnson                                9250487.0  ...
# Philip Morris International Inc.                 6312915.0  ...
# International Business Machines Corporation      4612125.0  ...
#
#                                                       city state         zip  \
# companyName
# Broadcom Inc.                                    Palo Alto    CA  95131-2313
# Mastercard Incorporated                           Purchase    NY       10577
# Johnson & Johnson                            New Brunswick    NJ       08933
# Philip Morris International Inc.             New York City    NY  10017-5592
# International Business Machines Corporation         Armonk    NY       10504
#
#                                                                                          image  \
# companyName
# Broadcom Inc.                                https://images.financialmodelingprep.com/symbo...
# Mastercard Incorporated                      https://images.financialmodelingprep.com/symbo...
# Johnson & Johnson                            https://images.financialmodelingprep.com/symbo...
# Philip Morris International Inc.             https://images.financialmodelingprep.com/symbo...
# International Business Machines Corporation  https://images.financialmodelingprep.com/symbo...
#
#                                                 ipoDate defaultImage  isEtf  \
# companyName
# Broadcom Inc.                                2009-08-06        False  False
# Mastercard Incorporated                      2006-05-25        False  False
# Johnson & Johnson                            1943-01-02        False  False
# Philip Morris International Inc.             2008-03-17        False  False
# International Business Machines Corporation  1915-09-24        False  False
#
#                                             isActivelyTrading  isAdr isFund
# companyName
# Broadcom Inc.                                            True  False  False
# Mastercard Incorporated                                  True  False  False
# Johnson & Johnson                                        True  False  False
# Philip Morris International Inc.                         True  False  False
# International Business Machines Corporation              True  False  False
#
# [5 rows x 35 columns]

# %%
pg.upload_dataframe(company_profiles_df, 'CompanyProfiles', if_exists='replace')
# Out:
# ✅ Data uploaded to table 'CompanyProfiles'.

# %%
def fetch_and_store_fundamentals(tickers, api_key, pg_manager):
    def get_quarterly_data(url_base, ticker, period):
        params = {
            'symbol': ticker,
            'period': period,
            'limit': 20,
            'apikey': api_key,
        }
        full_url = f"{url_base}?{'&'.join([f'{key}={value}' for key, value in params.items()])}"
        response = requests.get(full_url)
        if response.status_code == 200:
            try:
                df = pd.DataFrame(response.json())
                if not df.empty:
                    df['date'] = pd.to_datetime(df['date'])
                    df['period'] = period
                return df
            except ValueError:
                print(f"⚠️ JSON decoding failed for {url_base} - {period}")
                return pd.DataFrame()
        else:
            print(f"⚠️ Request failed for {url_base} - {period}")
            return pd.DataFrame()

    def get_all_fundamental_data(ticker):
        income_url = "https://financialmodelingprep.com/stable/income-statement"
        balance_url = "https://financialmodelingprep.com/stable/balance-sheet-statement"
        cashflow_url = "https://financialmodelingprep.com/stable/cash-flow-statement"

        all_merged = []

        for period in ['Q1', 'Q2', 'Q3', 'Q4']:
            income_df = get_quarterly_data(income_url, ticker, period)
            balance_df = get_quarterly_data(balance_url, ticker, period)
            cashflow_df = get_quarterly_data(cashflow_url, ticker, period)

            if not (income_df.empty or balance_df.empty or cashflow_df.empty):
                for df in [income_df, balance_df, cashflow_df]:
                    df.set_index('date', inplace=True)

                merged = income_df.join(balance_df, how='inner', lsuffix='_income', rsuffix='_balance')
                merged = merged.join(cashflow_df, how='inner', rsuffix='_cashflow')
                merged.reset_index(inplace=True)
                merged['period'] = period
                all_merged.append(merged)

        if all_merged:
            final_df = pd.concat(all_merged, ignore_index=True)
            final_df.sort_values(by='date', inplace=True)
            return final_df
        else:
            print(f"❌ No combined data for {ticker}")
            return pd.DataFrame()

    # Loop through tickers and push data
    for ticker in tickers:
        print(f"🔍 Fetching fundamentals for {ticker}...")
        df = get_all_fundamental_data(ticker)
        if not df.empty:
            table_name = f"{ticker}_FundamentalsData"
            try:
                pg_manager.upload_dataframe(df, table_name, if_exists='replace')
            except Exception as e:
                print(f"❌ Failed to upload data for {ticker}: {e}")
        else:
            print(f"⚠️ Skipping upload for {ticker} due to empty DataFrame.")

# %%
fetch_and_store_fundamentals(tickers, api_key, pg)
# Out:
# 🔍 Fetching fundamentals for AVGO...
# ✅ Data uploaded to table 'AVGO_FundamentalsData'.
# 🔍 Fetching fundamentals for MA...
# ✅ Data uploaded to table 'MA_FundamentalsData'.
# 🔍 Fetching fundamentals for JNJ...
# ✅ Data uploaded to table 'JNJ_FundamentalsData'.
# 🔍 Fetching fundamentals for PM...
# ✅ Data uploaded to table 'PM_FundamentalsData'.
# 🔍 Fetching fundamentals for IBM...
# ✅ Data uploaded to table 'IBM_FundamentalsData'.
# 🔍 Fetching fundamentals for NOW...
# ✅ Data uploaded to table 'NOW_FundamentalsData'.
# 🔍 Fetching fundamentals for TBB...
# ✅ Data uploaded to table 'TBB_FundamentalsData'.
# 🔍 Fetching fundamentals for RTX...
# ✅ Data uploaded to table 'RTX_FundamentalsData'.
# 🔍 Fetching fundamentals for ADBE...
# ✅ Data uploaded to table 'ADBE_FundamentalsData'.
# 🔍 Fetching fundamentals for SCHW...
# ✅ Data uploaded to table 'SCHW_FundamentalsData'.
# 🔍 Fetching fundamentals for TMO...
# ✅ Data uploaded to table 'TMO_FundamentalsData'.
# 🔍 Fetching fundamentals for C...
# ✅ Data uploaded to table 'C_FundamentalsData'.
# 🔍 Fetching fundamentals for GILD...
# ✅ Data uploaded to table 'GILD_FundamentalsData'.
# 🔍 Fetching fundamentals for PANW...
# ✅ Data uploaded to table 'PANW_FundamentalsData'.
# 🔍 Fetching fundamentals for CMCSA...
# ✅ Data uploaded to table 'CMCSA_FundamentalsData'.
# 🔍 Fetching fundamentals for MU...
# ✅ Data uploaded to table 'MU_FundamentalsData'.
# 🔍 Fetching fundamentals for APH...
# ✅ Data uploaded to table 'APH_FundamentalsData'.
# 🔍 Fetching fundamentals for BX...
# ✅ Data uploaded to table 'BX_FundamentalsData'.
# 🔍 Fetching fundamentals for ICE...
# ✅ Data uploaded to table 'ICE_FundamentalsData'.
# 🔍 Fetching fundamentals for WELL...
# ✅ Data uploaded to table 'WELL_FundamentalsData'.
# 🔍 Fetching fundamentals for AMT...
# ✅ Data uploaded to table 'AMT_FundamentalsData'.
# 🔍 Fetching fundamentals for BMYMP...
# ✅ Data uploaded to table 'BMYMP_FundamentalsData'.
# 🔍 Fetching fundamentals for SOJC...
# ✅ Data uploaded to table 'SOJC_FundamentalsData'.
# 🔍 Fetching fundamentals for CEG...
# ✅ Data uploaded to table 'CEG_FundamentalsData'.
# 🔍 Fetching fundamentals for HCA...
# ✅ Data uploaded to table 'HCA_FundamentalsData'.
# 🔍 Fetching fundamentals for DUKB...
# ✅ Data uploaded to table 'DUKB_FundamentalsData'.
# 🔍 Fetching fundamentals for IBKR...
# ✅ Data uploaded to table 'IBKR_FundamentalsData'.
# 🔍 Fetching fundamentals for ELV...
# ✅ Data uploaded to table 'ELV_FundamentalsData'.
# 🔍 Fetching fundamentals for INTC...
# ✅ Data uploaded to table 'INTC_FundamentalsData'.
# 🔍 Fetching fundamentals for AJG...
# ✅ Data uploaded to table 'AJG_FundamentalsData'.
# 🔍 Fetching fundamentals for TDG...
# ✅ Data uploaded to table 'TDG_FundamentalsData'.
# 🔍 Fetching fundamentals for CVS...
# ✅ Data uploaded to table 'CVS_FundamentalsData'.
# 🔍 Fetching fundamentals for RSG...
# ✅ Data uploaded to table 'RSG_FundamentalsData'.
# 🔍 Fetching fundamentals for ORLY...
# /tmp/ipykernel_2038/1196150514.py:48: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_df = pd.concat(all_merged, ignore_index=True)
# ✅ Data uploaded to table 'ORLY_FundamentalsData'.
# 🔍 Fetching fundamentals for MMM...
# ✅ Data uploaded to table 'MMM_FundamentalsData'.
# 🔍 Fetching fundamentals for DELL...
# ✅ Data uploaded to table 'DELL_FundamentalsData'.
# 🔍 Fetching fundamentals for SCCO...
# ✅ Data uploaded to table 'SCCO_FundamentalsData'.
# 🔍 Fetching fundamentals for APO...
# ✅ Data uploaded to table 'APO_FundamentalsData'.
# 🔍 Fetching fundamentals for ZTS...
# ✅ Data uploaded to table 'ZTS_FundamentalsData'.
# 🔍 Fetching fundamentals for ECL...
# ✅ Data uploaded to table 'ECL_FundamentalsData'.
# 🔍 Fetching fundamentals for SNPS...
# ✅ Data uploaded to table 'SNPS_FundamentalsData'.
# 🔍 Fetching fundamentals for RCL...
# ✅ Data uploaded to table 'RCL_FundamentalsData'.
# 🔍 Fetching fundamentals for BRK-B...
# ✅ Data uploaded to table 'BRK-B_FundamentalsData'.
# 🔍 Fetching fundamentals for NFLX...
# ✅ Data uploaded to table 'NFLX_FundamentalsData'.
# 🔍 Fetching fundamentals for HD...
# ✅ Data uploaded to table 'HD_FundamentalsData'.
# 🔍 Fetching fundamentals for TMUS...
# ✅ Data uploaded to table 'TMUS_FundamentalsData'.
# 🔍 Fetching fundamentals for WFC...
# ✅ Data uploaded to table 'WFC_FundamentalsData'.
# 🔍 Fetching fundamentals for AXP...
# ✅ Data uploaded to table 'AXP_FundamentalsData'.
# 🔍 Fetching fundamentals for ISRG...
# ✅ Data uploaded to table 'ISRG_FundamentalsData'.
# 🔍 Fetching fundamentals for VZ...
# ✅ Data uploaded to table 'VZ_FundamentalsData'.
# 🔍 Fetching fundamentals for TXN...
# ✅ Data uploaded to table 'TXN_FundamentalsData'.
# 🔍 Fetching fundamentals for SPGI...
# ✅ Data uploaded to table 'SPGI_FundamentalsData'.
# 🔍 Fetching fundamentals for BSX...
# ✅ Data uploaded to table 'BSX_FundamentalsData'.
# 🔍 Fetching fundamentals for TJX...
# ✅ Data uploaded to table 'TJX_FundamentalsData'.
# 🔍 Fetching fundamentals for RCIT...
# ✅ Data uploaded to table 'RCIT_FundamentalsData'.
# 🔍 Fetching fundamentals for PFE...
# ✅ Data uploaded to table 'PFE_FundamentalsData'.
# 🔍 Fetching fundamentals for COF...
# ✅ Data uploaded to table 'COF_FundamentalsData'.
# 🔍 Fetching fundamentals for CRWD...
# ✅ Data uploaded to table 'CRWD_FundamentalsData'.
# 🔍 Fetching fundamentals for LMT...
# ✅ Data uploaded to table 'LMT_FundamentalsData'.
# 🔍 Fetching fundamentals for COP...
# ✅ Data uploaded to table 'COP_FundamentalsData'.
# 🔍 Fetching fundamentals for MSFT...
# ✅ Data uploaded to table 'MSFT_FundamentalsData'.
# 🔍 Fetching fundamentals for BRK-A...
# ✅ Data uploaded to table 'BRK-A_FundamentalsData'.
# 🔍 Fetching fundamentals for ORCL...
# ✅ Data uploaded to table 'ORCL_FundamentalsData'.
# 🔍 Fetching fundamentals for BAC...
# ✅ Data uploaded to table 'BAC_FundamentalsData'.
# 🔍 Fetching fundamentals for UNH...
# ✅ Data uploaded to table 'UNH_FundamentalsData'.
# 🔍 Fetching fundamentals for CVX...
# ✅ Data uploaded to table 'CVX_FundamentalsData'.
# 🔍 Fetching fundamentals for NVDA...
# ✅ Data uploaded to table 'NVDA_FundamentalsData'.
# 🔍 Fetching fundamentals for TSLA...
# ✅ Data uploaded to table 'TSLA_FundamentalsData'.
# 🔍 Fetching fundamentals for COST...
# ✅ Data uploaded to table 'COST_FundamentalsData'.
# 🔍 Fetching fundamentals for ABBV...
# ✅ Data uploaded to table 'ABBV_FundamentalsData'.
# 🔍 Fetching fundamentals for GE...
# ✅ Data uploaded to table 'GE_FundamentalsData'.
# 🔍 Fetching fundamentals for ABT...
# ✅ Data uploaded to table 'ABT_FundamentalsData'.
# 🔍 Fetching fundamentals for MS...
# ✅ Data uploaded to table 'MS_FundamentalsData'.
# 🔍 Fetching fundamentals for MRK...
# ✅ Data uploaded to table 'MRK_FundamentalsData'.
# 🔍 Fetching fundamentals for BKNG...
# ✅ Data uploaded to table 'BKNG_FundamentalsData'.
# 🔍 Fetching fundamentals for CAT...
# ✅ Data uploaded to table 'CAT_FundamentalsData'.
# 🔍 Fetching fundamentals for BA...
# ✅ Data uploaded to table 'BA_FundamentalsData'.
# 🔍 Fetching fundamentals for NEE...
# ✅ Data uploaded to table 'NEE_FundamentalsData'.
# 🔍 Fetching fundamentals for APP...
# ✅ Data uploaded to table 'APP_FundamentalsData'.
# 🔍 Fetching fundamentals for AMAT...
# ✅ Data uploaded to table 'AMAT_FundamentalsData'.
# 🔍 Fetching fundamentals for ADP...
# ✅ Data uploaded to table 'ADP_FundamentalsData'.
# 🔍 Fetching fundamentals for LOW...
# ✅ Data uploaded to table 'LOW_FundamentalsData'.
# 🔍 Fetching fundamentals for VRTX...
# ✅ Data uploaded to table 'VRTX_FundamentalsData'.
# 🔍 Fetching fundamentals for LRCX...
# ✅ Data uploaded to table 'LRCX_FundamentalsData'.
# 🔍 Fetching fundamentals for KKR...
# ✅ Data uploaded to table 'KKR_FundamentalsData'.
# 🔍 Fetching fundamentals for MSTR...
# ✅ Data uploaded to table 'MSTR_FundamentalsData'.
# 🔍 Fetching fundamentals for PLD...
# ✅ Data uploaded to table 'PLD_FundamentalsData'.
# 🔍 Fetching fundamentals for CME...
# ✅ Data uploaded to table 'CME_FundamentalsData'.
# 🔍 Fetching fundamentals for SOJE...
# ✅ Data uploaded to table 'SOJE_FundamentalsData'.
# 🔍 Fetching fundamentals for SOJD...
# ✅ Data uploaded to table 'SOJD_FundamentalsData'.
# 🔍 Fetching fundamentals for NKE...
# ✅ Data uploaded to table 'NKE_FundamentalsData'.
# 🔍 Fetching fundamentals for FI...
# ✅ Data uploaded to table 'FI_FundamentalsData'.
# 🔍 Fetching fundamentals for SHW...
# ✅ Data uploaded to table 'SHW_FundamentalsData'.
# 🔍 Fetching fundamentals for EQIX...
# ✅ Data uploaded to table 'EQIX_FundamentalsData'.
# 🔍 Fetching fundamentals for ABNB...
# ✅ Data uploaded to table 'ABNB_FundamentalsData'.
# 🔍 Fetching fundamentals for PH...
# ✅ Data uploaded to table 'PH_FundamentalsData'.
# 🔍 Fetching fundamentals for CI...
# ✅ Data uploaded to table 'CI_FundamentalsData'.
# 🔍 Fetching fundamentals for CDNS...
# ✅ Data uploaded to table 'CDNS_FundamentalsData'.
# 🔍 Fetching fundamentals for FTNT...
# ✅ Data uploaded to table 'FTNT_FundamentalsData'.
# 🔍 Fetching fundamentals for AAPL...
# ✅ Data uploaded to table 'AAPL_FundamentalsData'.
# 🔍 Fetching fundamentals for WMT...
# ✅ Data uploaded to table 'WMT_FundamentalsData'.
# 🔍 Fetching fundamentals for XOM...
# ✅ Data uploaded to table 'XOM_FundamentalsData'.
# 🔍 Fetching fundamentals for KO...
# ✅ Data uploaded to table 'KO_FundamentalsData'.
# 🔍 Fetching fundamentals for CRM...
# ✅ Data uploaded to table 'CRM_FundamentalsData'.
# 🔍 Fetching fundamentals for MCD...
# ✅ Data uploaded to table 'MCD_FundamentalsData'.
# 🔍 Fetching fundamentals for DIS...
# ✅ Data uploaded to table 'DIS_FundamentalsData'.
# 🔍 Fetching fundamentals for GS...
# ✅ Data uploaded to table 'GS_FundamentalsData'.
# 🔍 Fetching fundamentals for UBER...
# ✅ Data uploaded to table 'UBER_FundamentalsData'.
# 🔍 Fetching fundamentals for QCOM...
# ✅ Data uploaded to table 'QCOM_FundamentalsData'.
# 🔍 Fetching fundamentals for AMGN...
# ✅ Data uploaded to table 'AMGN_FundamentalsData'.
# 🔍 Fetching fundamentals for HON...
# ✅ Data uploaded to table 'HON_FundamentalsData'.
# 🔍 Fetching fundamentals for DE...
# ✅ Data uploaded to table 'DE_FundamentalsData'.
# 🔍 Fetching fundamentals for UNP...
# ✅ Data uploaded to table 'UNP_FundamentalsData'.
# 🔍 Fetching fundamentals for GEV...
# ✅ Data uploaded to table 'GEV_FundamentalsData'.
# 🔍 Fetching fundamentals for ANET...
# ✅ Data uploaded to table 'ANET_FundamentalsData'.
# 🔍 Fetching fundamentals for MMC...
# ✅ Data uploaded to table 'MMC_FundamentalsData'.
# 🔍 Fetching fundamentals for ADI...
# ✅ Data uploaded to table 'ADI_FundamentalsData'.
# 🔍 Fetching fundamentals for KLAC...
# ✅ Data uploaded to table 'KLAC_FundamentalsData'.
# 🔍 Fetching fundamentals for SBUX...
# ✅ Data uploaded to table 'SBUX_FundamentalsData'.
# 🔍 Fetching fundamentals for MO...
# ✅ Data uploaded to table 'MO_FundamentalsData'.
# 🔍 Fetching fundamentals for BMY...
# ✅ Data uploaded to table 'BMY_FundamentalsData'.
# 🔍 Fetching fundamentals for SO...
# ✅ Data uploaded to table 'SO_FundamentalsData'.
# 🔍 Fetching fundamentals for WM...
# ✅ Data uploaded to table 'WM_FundamentalsData'.
# 🔍 Fetching fundamentals for DASH...
# ✅ Data uploaded to table 'DASH_FundamentalsData'.
# 🔍 Fetching fundamentals for CTAS...
# ✅ Data uploaded to table 'CTAS_FundamentalsData'.
# 🔍 Fetching fundamentals for DUK...
# ✅ Data uploaded to table 'DUK_FundamentalsData'.
# 🔍 Fetching fundamentals for MCK...
# ✅ Data uploaded to table 'MCK_FundamentalsData'.
# 🔍 Fetching fundamentals for MCO...
# ✅ Data uploaded to table 'MCO_FundamentalsData'.
# 🔍 Fetching fundamentals for MDLZ...
# ✅ Data uploaded to table 'MDLZ_FundamentalsData'.
# 🔍 Fetching fundamentals for UPS...
# ✅ Data uploaded to table 'UPS_FundamentalsData'.
# 🔍 Fetching fundamentals for AMZN...
# ✅ Data uploaded to table 'AMZN_FundamentalsData'.
# 🔍 Fetching fundamentals for JPM...
# ✅ Data uploaded to table 'JPM_FundamentalsData'.
# 🔍 Fetching fundamentals for GOOGL...
# ✅ Data uploaded to table 'GOOGL_FundamentalsData'.
# 🔍 Fetching fundamentals for GOOG...
# ✅ Data uploaded to table 'GOOG_FundamentalsData'.
# 🔍 Fetching fundamentals for LLY...
# ✅ Data uploaded to table 'LLY_FundamentalsData'.
# 🔍 Fetching fundamentals for META...
# ✅ Data uploaded to table 'META_FundamentalsData'.
# 🔍 Fetching fundamentals for V...
# ✅ Data uploaded to table 'V_FundamentalsData'.
# 🔍 Fetching fundamentals for PG...
# ✅ Data uploaded to table 'PG_FundamentalsData'.
# 🔍 Fetching fundamentals for PLTR...
# ✅ Data uploaded to table 'PLTR_FundamentalsData'.
# 🔍 Fetching fundamentals for CSCO...
# ✅ Data uploaded to table 'CSCO_FundamentalsData'.
# 🔍 Fetching fundamentals for INTU...
# ✅ Data uploaded to table 'INTU_FundamentalsData'.
# 🔍 Fetching fundamentals for T...
# ✅ Data uploaded to table 'T_FundamentalsData'.
# 🔍 Fetching fundamentals for AMD...
# ✅ Data uploaded to table 'AMD_FundamentalsData'.
# 🔍 Fetching fundamentals for PEP...
# ✅ Data uploaded to table 'PEP_FundamentalsData'.
# 🔍 Fetching fundamentals for PGR...
# ✅ Data uploaded to table 'PGR_FundamentalsData'.
# 🔍 Fetching fundamentals for BLK...
# ✅ Data uploaded to table 'BLK_FundamentalsData'.
# 🔍 Fetching fundamentals for SYK...
# ✅ Data uploaded to table 'SYK_FundamentalsData'.
# 🔍 Fetching fundamentals for DHR...
# ✅ Data uploaded to table 'DHR_FundamentalsData'.
# 🔍 Fetching fundamentals for GD...
# ✅ Data uploaded to table 'GD_FundamentalsData'.
# 🔍 Fetching fundamentals for WMB...
# ✅ Data uploaded to table 'WMB_FundamentalsData'.
# 🔍 Fetching fundamentals for CL...
# ✅ Data uploaded to table 'CL_FundamentalsData'.
# 🔍 Fetching fundamentals for CVNA...
# ✅ Data uploaded to table 'CVNA_FundamentalsData'.
# 🔍 Fetching fundamentals for MAR...
# ✅ Data uploaded to table 'MAR_FundamentalsData'.
# 🔍 Fetching fundamentals for ITW...
# ✅ Data uploaded to table 'ITW_FundamentalsData'.
# 🔍 Fetching fundamentals for PYPL...
# ✅ Data uploaded to table 'PYPL_FundamentalsData'.
# 🔍 Fetching fundamentals for HWM...
# ✅ Data uploaded to table 'HWM_FundamentalsData'.
# 🔍 Fetching fundamentals for CMG...
# ✅ Data uploaded to table 'CMG_FundamentalsData'.
# 🔍 Fetching fundamentals for PNC...
# ✅ Data uploaded to table 'PNC_FundamentalsData'.
# 🔍 Fetching fundamentals for NOC...
# ✅ Data uploaded to table 'NOC_FundamentalsData'.
# 🔍 Fetching fundamentals for SNOW...
# ✅ Data uploaded to table 'SNOW_FundamentalsData'.
# 🔍 Fetching fundamentals for MSI...
# ✅ Data uploaded to table 'MSI_FundamentalsData'.
# 🔍 Fetching fundamentals for USB...
# ✅ Data uploaded to table 'USB_FundamentalsData'.
# 🔍 Fetching fundamentals for EMR...
# ✅ Data uploaded to table 'EMR_FundamentalsData'.
# 🔍 Fetching fundamentals for EPD...
# ✅ Data uploaded to table 'EPD_FundamentalsData'.
# 🔍 Fetching fundamentals for WDAY...
# ✅ Data uploaded to table 'WDAY_FundamentalsData'.
# 🔍 Fetching fundamentals for CRWV...
# ✅ Data uploaded to table 'CRWV_FundamentalsData'.
# 🔍 Fetching fundamentals for HOOD...
# ✅ Data uploaded to table 'HOOD_FundamentalsData'.
# 🔍 Fetching fundamentals for RBLX...
# ✅ Data uploaded to table 'RBLX_FundamentalsData'.
# 🔍 Fetching fundamentals for BK...
# ✅ Data uploaded to table 'BK_FundamentalsData'.
# 🔍 Fetching fundamentals for COIN...
# ✅ Data uploaded to table 'COIN_FundamentalsData'.
# 🔍 Fetching fundamentals for ADSK...
# ✅ Data uploaded to table 'ADSK_FundamentalsData'.
# 🔍 Fetching fundamentals for KMI...
# ✅ Data uploaded to table 'KMI_FundamentalsData'.
# 🔍 Fetching fundamentals for NET...
# ✅ Data uploaded to table 'NET_FundamentalsData'.
# 🔍 Fetching fundamentals for APD...
# ✅ Data uploaded to table 'APD_FundamentalsData'.
# 🔍 Fetching fundamentals for EOG...
# ✅ Data uploaded to table 'EOG_FundamentalsData'.
# 🔍 Fetching fundamentals for AZO...
# ✅ Data uploaded to table 'AZO_FundamentalsData'.
# 🔍 Fetching fundamentals for TRV...
# ✅ Data uploaded to table 'TRV_FundamentalsData'.
# 🔍 Fetching fundamentals for MNST...
# ✅ Data uploaded to table 'MNST_FundamentalsData'.
# 🔍 Fetching fundamentals for AXON...
# ✅ Data uploaded to table 'AXON_FundamentalsData'.
# 🔍 Fetching fundamentals for ROP...
# ✅ Data uploaded to table 'ROP_FundamentalsData'.
# 🔍 Fetching fundamentals for ET...
# ✅ Data uploaded to table 'ET_FundamentalsData'.
# 🔍 Fetching fundamentals for CARR...
# ✅ Data uploaded to table 'CARR_FundamentalsData'.
# 🔍 Fetching fundamentals for CSX...
# ✅ Data uploaded to table 'CSX_FundamentalsData'.
# 🔍 Fetching fundamentals for HLT...
# ✅ Data uploaded to table 'HLT_FundamentalsData'.
# 🔍 Fetching fundamentals for FCX...
# ✅ Data uploaded to table 'FCX_FundamentalsData'.
# 🔍 Fetching fundamentals for DLR...
# ✅ Data uploaded to table 'DLR_FundamentalsData'.
# 🔍 Fetching fundamentals for MRVL...
# ✅ Data uploaded to table 'MRVL_FundamentalsData'.
# 🔍 Fetching fundamentals for VST...
# ✅ Data uploaded to table 'VST_FundamentalsData'.
# 🔍 Fetching fundamentals for NEM...
# ✅ Data uploaded to table 'NEM_FundamentalsData'.
# 🔍 Fetching fundamentals for PAYX...
# ✅ Data uploaded to table 'PAYX_FundamentalsData'.
# 🔍 Fetching fundamentals for NSC...
# ✅ Data uploaded to table 'NSC_FundamentalsData'.
# 🔍 Fetching fundamentals for AFL...
# ✅ Data uploaded to table 'AFL_FundamentalsData'.
# 🔍 Fetching fundamentals for COR...
# ✅ Data uploaded to table 'COR_FundamentalsData'.
# 🔍 Fetching fundamentals for ALL...
# ✅ Data uploaded to table 'ALL_FundamentalsData'.
# 🔍 Fetching fundamentals for CHTR...
# ✅ Data uploaded to table 'CHTR_FundamentalsData'.
# 🔍 Fetching fundamentals for AEP...
# ✅ Data uploaded to table 'AEP_FundamentalsData'.
# 🔍 Fetching fundamentals for LNG...
# ✅ Data uploaded to table 'LNG_FundamentalsData'.
# 🔍 Fetching fundamentals for MET...
# ✅ Data uploaded to table 'MET_FundamentalsData'.
# 🔍 Fetching fundamentals for PWR...
# ✅ Data uploaded to table 'PWR_FundamentalsData'.
# 🔍 Fetching fundamentals for TFC...
# ✅ Data uploaded to table 'TFC_FundamentalsData'.
# 🔍 Fetching fundamentals for PSA...
# ✅ Data uploaded to table 'PSA_FundamentalsData'.
# 🔍 Fetching fundamentals for SPG...
# ✅ Data uploaded to table 'SPG_FundamentalsData'.
# 🔍 Fetching fundamentals for FDX...
# ✅ Data uploaded to table 'FDX_FundamentalsData'.
# 🔍 Fetching fundamentals for GWW...
# ✅ Data uploaded to table 'GWW_FundamentalsData'.
# 🔍 Fetching fundamentals for MPLX...
# ✅ Data uploaded to table 'MPLX_FundamentalsData'.
# 🔍 Fetching fundamentals for REGN...
# ✅ Data uploaded to table 'REGN_FundamentalsData'.
# 🔍 Fetching fundamentals for OKE...
# ✅ Data uploaded to table 'OKE_FundamentalsData'.
# 🔍 Fetching fundamentals for O...
# ✅ Data uploaded to table 'O_FundamentalsData'.
# 🔍 Fetching fundamentals for DFS...
# ✅ Data uploaded to table 'DFS_FundamentalsData'.
# 🔍 Fetching fundamentals for AIG...
# ✅ Data uploaded to table 'AIG_FundamentalsData'.
# 🔍 Fetching fundamentals for SRE...
# ✅ Data uploaded to table 'SRE_FundamentalsData'.
# 🔍 Fetching fundamentals for BDX...
# ✅ Data uploaded to table 'BDX_FundamentalsData'.
# 🔍 Fetching fundamentals for SREA...
# ✅ Data uploaded to table 'SREA_FundamentalsData'.
# 🔍 Fetching fundamentals for AMP...
# ✅ Data uploaded to table 'AMP_FundamentalsData'.
# 🔍 Fetching fundamentals for MPC...
# ✅ Data uploaded to table 'MPC_FundamentalsData'.
# 🔍 Fetching fundamentals for NDAQ...
# ✅ Data uploaded to table 'NDAQ_FundamentalsData'.
# 🔍 Fetching fundamentals for PCAR...
# ✅ Data uploaded to table 'PCAR_FundamentalsData'.
# 🔍 Fetching fundamentals for CTVA...
# ✅ Data uploaded to table 'CTVA_FundamentalsData'.
# 🔍 Fetching fundamentals for CPRT...
# ✅ Data uploaded to table 'CPRT_FundamentalsData'.
# 🔍 Fetching fundamentals for FAST...
# ✅ Data uploaded to table 'FAST_FundamentalsData'.
# 🔍 Fetching fundamentals for D...
# ✅ Data uploaded to table 'D_FundamentalsData'.
# 🔍 Fetching fundamentals for ROST...
# ✅ Data uploaded to table 'ROST_FundamentalsData'.
# 🔍 Fetching fundamentals for ZS...
# ✅ Data uploaded to table 'ZS_FundamentalsData'.
# 🔍 Fetching fundamentals for VEEV...
# ✅ Data uploaded to table 'VEEV_FundamentalsData'.
# 🔍 Fetching fundamentals for PSX...
# ✅ Data uploaded to table 'PSX_FundamentalsData'.
# 🔍 Fetching fundamentals for SLB...
# ✅ Data uploaded to table 'SLB_FundamentalsData'.
# 🔍 Fetching fundamentals for URI...
# ✅ Data uploaded to table 'URI_FundamentalsData'.
# 🔍 Fetching fundamentals for LHX...
# ✅ Data uploaded to table 'LHX_FundamentalsData'.
# 🔍 Fetching fundamentals for GM...
# ✅ Data uploaded to table 'GM_FundamentalsData'.
# 🔍 Fetching fundamentals for EW...
# ✅ Data uploaded to table 'EW_FundamentalsData'.
# 🔍 Fetching fundamentals for CMI...
# ✅ Data uploaded to table 'CMI_FundamentalsData'.
# 🔍 Fetching fundamentals for VRSK...
# ✅ Data uploaded to table 'VRSK_FundamentalsData'.
# 🔍 Fetching fundamentals for KDP...
# ✅ Data uploaded to table 'KDP_FundamentalsData'.
# 🔍 Fetching fundamentals for KMB...
# ✅ Data uploaded to table 'KMB_FundamentalsData'.
